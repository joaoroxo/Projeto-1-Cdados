# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: João Nogueira Roxo da Fonseca

# %% [markdown]
# ## Pergunta (s) a ser respondida

# %% [markdown]
# Com a criação do Mercosul, os países que ingressaram melhoraram sua exportações em comparação aos países que somente se associaram? Decorrente a isso seu PIB também cresceu diante a mesma comparação?

# %% [markdown]
# ## Explicação da hipótese e mecanismo

# %% [markdown]
#    Os países pertencentes ao Mercosul exportaram mais do que países somentes associados a esse bloco, já que o Mercosul tem vantagens para que a exportação aconteça de uma forma mais acentuada, o que não acontece para os países somentes associados pelo fato dos países dos próprios não adotarem a Tec(Tarifa externa comun), uma dos principais incentivos para essa exportação. Sendo assim os paises que pertencem ao bloco Mercosul também terão um maior aumento no pib em relação aos paises associados.
#
# Artigo no qual a hipótese foi embasada: https://www.xportjr.com.br/single-post/2019/04/16/Mercosul-vantagens-para-exporta%C3%A7%C3%B5es-brasileiras

# %% [markdown]
# ## Bases de dados usadas

# %% [markdown]
# Link para o dowload dos dados: https://www.gapminder.org/data/.
# As variaveis que foram utilizadas para responder as perguntas foram: Exportação dos países, GDP ou PIB dos países.

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# ### Importando Bibliotecas##

# %%
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Lendo base de dados via EXCEL.

# %%
dadospib = pd.read_excel('total_gdp_us_inflation_adjusted.xlsx') #pib
dadosexp = pd.read_excel('bx_gsr_gnfs_cd.xlsx') #exportação

# %% [markdown]
# ### Trocando indice da tabela.

# %%
dadospib_country = dadospib.set_index("country")
dadosexp_country = dadosexp.set_index("country")

# %% [markdown]
# ### Criando listas dos países membros e associdos.

# %%
mercosul = ["Argentina", "Brazil", "Paraguay", "Uruguay", "Venezuela"] #Membros
associados = ["Chile", "Guyana", "Ecuador", "Colombia", "Peru", "Suriname"] #Associados

# %% [markdown]
# ### Lista de anos à ser observados (desde a criação do bloco).

# %%
anos = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %% [markdown]
# ### Criando coluna de membros, associados e resto do mundo.

# %%
dadospib_country.loc[:, "MERCOSUL"] = 'Não'
dadospib_country.loc[mercosul, "MERCOSUL"]='Mercosul'
dadospib_country.loc[associados, "MERCOSUL"]='Associados'

dadosexp_country.loc[:,"MERCOSUL"]= 'Não'
dadosexp_country.loc[mercosul, "MERCOSUL"]= 'Mercosul'
dadosexp_country.loc[associados, "MERCOSUL"]= 'Associados'

# %%
dados1 = dadospib_country.loc[dadospib_country["MERCOSUL"] == 'Mercosul']
dados1
# Out:
#                    1960          1961          1962          1963  \
# country
# Argentina  1.160000e+11  1.220000e+11  1.210000e+11  1.140000e+11
# Brazil     2.470000e+11  2.730000e+11  2.870000e+11  2.890000e+11
# Paraguay   1.950000e+09  2.090000e+09  2.150000e+09  2.260000e+09
# Uruguay    1.390000e+10  1.420000e+10  1.400000e+10  1.400000e+10
# Venezuela  1.010000e+11  1.050000e+11  1.140000e+11  1.180000e+11
#
#                    1964          1965          1966          1967  \
# country
# Argentina  1.260000e+11  1.390000e+11  1.380000e+11  1.430000e+11
# Brazil     3.000000e+11  3.090000e+11  3.220000e+11  3.370000e+11
#                   2011          2012          2013          2014  \
# country
# Chile     2.320000e+11  2.440000e+11  2.540000e+11  2.590000e+11
# Colombia  3.060000e+11  3.180000e+11  3.340000e+11  3.480000e+11
# Ecuador   7.500000e+10  7.930000e+10  8.320000e+10  8.630000e+10
# Guyana    2.390000e+09  2.520000e+09  2.640000e+09  2.750000e+09
# Peru      1.570000e+11  1.660000e+11  1.760000e+11  1.800000e+11
# Suriname  4.620000e+09  4.750000e+09  4.890000e+09  4.900000e+09
#
#                   2015          2016          2017    MERCOSUL
# country
# Chile     2.650000e+11  2.680000e+11  2.720000e+11  Associados
# Colombia  3.590000e+11  3.660000e+11  3.730000e+11  Associados
# Ecuador   8.640000e+10  8.510000e+10  8.760000e+10  Associados
# Guyana    2.830000e+09  2.930000e+09  3.010000e+09  Associados
# Peru      1.860000e+11  1.940000e+11  1.990000e+11  Associados
# Suriname  4.770000e+09  4.530000e+09  4.530000e+09  Associados
#
# [6 rows x 59 columns]

# %% [markdown]
# ### Criando coluna somente de associados (afim de facilitar a criação do primeiro gráfico).

# %%
dadospib_country.loc[:, "ASSOCIADOS"]=0
dadospib_country.loc[associados, "ASSOCIADOS"]=1

dadosexp_country.loc[:, "ASSOCIADOS"]=0
dadosexp_country.loc[associados, "ASSOCIADOS"]=1

# %% [markdown]
# ### Graficos comparando PIB, Exportação entre países membros e associados.

# %%
dadospib_mercosul = dadospib_country.loc[mercosul]
dadosexp_mercosul = dadosexp_country.loc[mercosul]

dadospib_associados = dadospib_country.loc[associados]
dadosexp_associados = dadosexp_country.loc[associados]

# %%
transpor_m = dadospib_mercosul.transpose()
transpor_qnt_m = transpor_m[:-2]
mercosul1 = transpor_qnt_m.loc[(transpor_qnt_m.index>1990) & (transpor_qnt_m.index<2017),:].transpose()
soma_m = mercosul1.sum()


transpor_a = dadospib_associados.transpose()
transpor_qnt_a = transpor_a[:-2]
associados1 = transpor_qnt_a.loc[(transpor_qnt_a.index>1990) & (transpor_qnt_a.index<2017),:].transpose()
soma_a = associados1.sum()

# %%
transpor_exp_m = dadosexp_mercosul.transpose()
transpor_qnt_exp_m = transpor_exp_m[:-2]
mercosul2 = transpor_qnt_exp_m.loc[(transpor_qnt_exp_m.index>1990) & (transpor_qnt_exp_m.index<2017),:].transpose()
soma_exp_m = mercosul2.sum()


transpor_exp_a = dadosexp_associados.transpose()
transpor_qnt_exp_a = transpor_exp_a[:-2]
associados2 = transpor_qnt_exp_a.loc[(transpor_qnt_exp_a.index>1990) & (transpor_qnt_exp_a.index<2017),:].transpose()
soma_exp_a = associados2.sum()

# %% [markdown]
# #### Comparação PIB, desde a criação do bloco até 2016, de membros e associados.

# %%
plt.plot(anos, soma_a, label="pib associados")
plt.plot(anos, soma_m, label="pib mercosul")
plt.title("Comparação PIB ")
plt.xlabel("Anos")
plt.ylabel("PIB")
plt.legend()
plt.show()

# %% [markdown]
# #### Comparação Exportação, desde a criação do bloco até 2016, de membros associados.

# %%
plt.plot(anos, soma_exp_a, label="exp associados")
plt.plot(anos, soma_exp_m, label="exp mercosul")
plt.title("Comparação Exportação")
plt.xlabel("Anos")
plt.ylabel("PIB")
plt.legend()
plt.show()

# %% [markdown]
# #### Comparação PIB e Exportação, desde a criação do bloco até 2016, de membros e associados.

# %%
plt.plot(anos, soma_a, label="pib associados")
plt.plot(anos, soma_m, label="pib mercosul")
plt.plot(anos, soma_exp_a, label="exp associados")
plt.plot(anos, soma_exp_m, label="exp mercosul")
plt.title("Comparação PIB e Exportação")
plt.xlabel("Anos")
plt.ylabel("PIB")
plt.legend()
plt.show()

# %% [markdown]
# ### Plotando gráficos Boxplot.

# %% [markdown]
# #### Vizualização intuitiva da média, mediana e assimetria.

# %% [markdown]
# #### Diante a exportação (depois de 10 anos de criação do bloco)

# %%
dadosexp_country.loc[ ~(dadosexp_country.MERCOSUL=="Não") ].boxplot(column=2001, by="MERCOSUL")

# %% [markdown]
# #### Diante ao PIB (depois de 10 anos de criação do bloco

# %%
dadospib_country.loc[ ~(dadospib_country.MERCOSUL=="Não") ].boxplot(column=2001, by="MERCOSUL")

# %% [markdown]
# ### Em seguida plotando em forma de histograma.
# ### Esses graficos ajudam a vizualizar a distribuição dos dados.

# %% [markdown]
# #### PIB

# %%
dadospib_country.hist(column=2001, by="MERCOSUL");

# %% [markdown]
# #### Exportação

# %%
dadosexp_country.hist(column=2001, by="MERCOSUL");

# %% [markdown]
# ### Criando join para graficos com duas variaveis.

# %%
tabela_pib_exp = dadospib_country.join(dadosexp_country, how="inner", lsuffix="_PIB", rsuffix="_EXP")
tabela_pib_exp
# Out:
#                                     1960_PIB      1961_PIB      1962_PIB  \
# country
# Afghanistan                              NaN           NaN           NaN
# Albania                                  NaN           NaN           NaN
# Algeria                         2.740000e+10  2.370000e+10  1.900000e+10
# Angola                                   NaN           NaN           NaN
# Antigua and Barbuda                      NaN           NaN           NaN
# Argentina                       1.160000e+11  1.220000e+11  1.210000e+11
# Armenia                                  NaN           NaN           NaN
# Australia                       1.990000e+11  2.040000e+11  2.070000e+11
# Austria                         9.180000e+10  9.690000e+10  9.950000e+10
# Azerbaijan                               NaN           NaN           NaN
# Bahamas                         1.940000e+09  2.150000e+09  2.370000e+09
# Bahrain                                  NaN           NaN           NaN
# Bangladesh                      1.790000e+10  1.890000e+10  2.000000e+10
# Barbados                                 NaN           NaN           NaN
# Belarus                                  NaN           NaN           NaN
# Belgium                         1.210000e+11  1.270000e+11  1.330000e+11
# Belize                          9.870000e+07  1.040000e+08  1.090000e+08
# Benin                           1.270000e+09  1.310000e+09  1.260000e+09
# Bhutan                                   NaN           NaN           NaN
# Bolivia                         4.820000e+09  4.920000e+09  5.190000e+09
# Bosnia and Herzegovina                   NaN           NaN           NaN
# Botswana                        2.050000e+08  2.180000e+08  2.330000e+08
# Brazil                          2.470000e+11  2.730000e+11  2.870000e+11
# Brunei                                   NaN           NaN           NaN
# Bulgaria                                 NaN           NaN           NaN
# Burkina Faso                    1.150000e+09  1.200000e+09  1.270000e+09
# Burundi                         5.970000e+08  5.150000e+08  5.610000e+08
# Cambodia                                 NaN           NaN           NaN
# Cameroon                        4.950000e+09  5.010000e+09  5.160000e+09
# Canada                          3.160000e+11  3.260000e+11  3.500000e+11
# ...                                      ...           ...           ...
# Sri Lanka                                NaN  5.920000e+09  6.150000e+09
# St. Kitts and Nevis                      NaN           NaN           NaN
# St. Lucia                                NaN           NaN           NaN
# St. Vincent and the Grenadines  1.420000e+08  1.480000e+08  1.540000e+08
# Sudan                           9.320000e+09  9.320000e+09  9.970000e+09
# Suriname                                 NaN           NaN           NaN
# Sweden                          1.360000e+11  1.440000e+11  1.500000e+11
# Switzerland                              NaN           NaN           NaN
# Tajikistan                               NaN           NaN           NaN
# Tanzania                                 NaN           NaN           NaN
# Thailand                        1.560000e+10  1.650000e+10  1.770000e+10
# Timor-Leste                              NaN           NaN           NaN
# Togo                            5.520000e+08  6.190000e+08  6.420000e+08
# Tonga                                    NaN           NaN           NaN
# Trinidad and Tobago             4.280000e+09  4.880000e+09  5.010000e+09
# Tunisia                                  NaN           NaN           NaN
# Turkey                          8.720000e+10  8.820000e+10  9.320000e+10
# Tuvalu                                   NaN           NaN           NaN
# Uganda                                   NaN           NaN           NaN
# Ukraine                                  NaN           NaN           NaN
# United Kingdom                  7.250000e+11  7.430000e+11  7.530000e+11
# United States                   3.080000e+12  3.150000e+12  3.340000e+12
# Uruguay                         1.390000e+10  1.420000e+10  1.400000e+10
# Uzbekistan                               NaN           NaN           NaN
# Vanuatu                                  NaN           NaN           NaN
# Venezuela                       1.010000e+11  1.050000e+11  1.140000e+11
# Vietnam                                  NaN           NaN           NaN
# Yemen                                    NaN           NaN           NaN
# Zambia                          4.590000e+09  4.660000e+09  4.540000e+09
# Zimbabwe                        3.360000e+09  3.580000e+09  3.630000e+09
#
#                                     1963_PIB      1964_PIB      1965_PIB  \
# country
# Afghanistan                              NaN           NaN           NaN
# Albania                                  NaN           NaN           NaN
# Algeria                         2.560000e+10  2.710000e+10  2.870000e+10
# Angola                                   NaN           NaN           NaN
# Antigua and Barbuda                      NaN           NaN           NaN
# Argentina                       1.140000e+11  1.260000e+11  1.390000e+11
# Armenia                                  NaN           NaN           NaN
# Australia                       2.200000e+11  2.350000e+11  2.490000e+11
# Austria                         1.040000e+11  1.100000e+11  1.140000e+11
# Azerbaijan                               NaN           NaN           NaN
# Bahamas                         2.620000e+09  2.900000e+09  3.200000e+09
# Bahrain                                  NaN           NaN           NaN
# Bangladesh                      1.990000e+10  2.210000e+10  2.240000e+10
# Barbados                                 NaN           NaN           NaN
# Belarus                                  NaN           NaN           NaN
# Belgium                         1.390000e+11  1.490000e+11  1.540000e+11
# Belize                          1.140000e+08  1.200000e+08  1.260000e+08
# Benin                           1.320000e+09  1.410000e+09  1.480000e+09
# Bhutan                                   NaN           NaN           NaN
# Bolivia                         5.530000e+09  5.790000e+09  6.120000e+09
# Bosnia and Herzegovina                   NaN           NaN           NaN
# Botswana                        2.460000e+08  2.630000e+08  2.780000e+08
# Brazil                          2.890000e+11  3.000000e+11  3.090000e+11
# Brunei                                   NaN           NaN           NaN
# Bulgaria                                 NaN           NaN           NaN
# Burkina Faso                    1.260000e+09  1.290000e+09  1.330000e+09
# Burundi                         5.840000e+08  6.210000e+08  6.460000e+08
# Cambodia                                 NaN           NaN           NaN
# Cameroon                        5.360000e+09  5.540000e+09  5.660000e+09
# Canada                          3.680000e+11  3.920000e+11  4.180000e+11
# ...                                      ...           ...           ...
# Sri Lanka                       6.310000e+09  6.550000e+09  6.720000e+09
# St. Kitts and Nevis                      NaN           NaN           NaN
# St. Lucia                                NaN           NaN           NaN
# St. Vincent and the Grenadines  1.440000e+08  1.490000e+08  1.510000e+08
# Sudan                           9.680000e+09  9.580000e+09  1.020000e+10
# Suriname                                 NaN           NaN           NaN
# Sweden                          1.580000e+11  1.680000e+11  1.750000e+11
# Switzerland                              NaN           NaN           NaN
# Tajikistan                               NaN           NaN           NaN
# Tanzania                                 NaN           NaN           NaN
# Thailand                        1.910000e+10  2.040000e+10  2.210000e+10
# Timor-Leste                              NaN           NaN           NaN
# Togo                            6.740000e+08  7.710000e+08  8.900000e+08
# Tonga                                    NaN           NaN           NaN
# Trinidad and Tobago             5.290000e+09  5.690000e+09  5.730000e+09
# Tunisia                                  NaN           NaN  5.060000e+09
# Turkey                          1.020000e+11  1.070000e+11  1.100000e+11
# Tuvalu                                   NaN           NaN           NaN
# Uganda                                   NaN           NaN           NaN
# Ukraine                                  NaN           NaN           NaN
# United Kingdom                  7.830000e+11  8.220000e+11  8.450000e+11
# United States                   3.490000e+12  3.690000e+12  3.930000e+12
# Uruguay                         1.400000e+10  1.440000e+10  1.450000e+10
# Uzbekistan                               NaN           NaN           NaN
# Vanuatu                                  NaN           NaN           NaN
# Venezuela                       1.180000e+11  1.310000e+11  1.370000e+11
# Vietnam                                  NaN           NaN           NaN
# Yemen                                    NaN           NaN           NaN
# Zambia                          4.690000e+09  5.260000e+09  6.140000e+09
# Zimbabwe                        3.850000e+09  3.810000e+09  4.000000e+09
#
#                                     1966_PIB      1967_PIB      1968_PIB  \
# country
# Afghanistan                              NaN           NaN           NaN
# Albania                                  NaN           NaN           NaN
# Algeria                         2.740000e+10  2.990000e+10  3.320000e+10
# Angola                                   NaN           NaN           NaN
# Antigua and Barbuda                      NaN           NaN           NaN
# Argentina                       1.380000e+11  1.430000e+11  1.500000e+11
# Armenia                                  NaN           NaN           NaN
# Australia                       2.550000e+11  2.710000e+11  2.850000e+11
# Austria                         1.200000e+11  1.240000e+11  1.290000e+11
# Azerbaijan                               NaN           NaN           NaN
# Bahamas                         3.490000e+09  3.830000e+09  4.150000e+09
# Bahrain                                  NaN           NaN           NaN
# Bangladesh                      2.300000e+10  2.260000e+10  2.470000e+10
# Barbados                                 NaN           NaN           NaN
# Belarus                                  NaN           NaN           NaN
# Belgium                         1.590000e+11  1.650000e+11  1.720000e+11
# Belize                          1.320000e+08  1.380000e+08  1.480000e+08
# Benin                           1.540000e+09  1.550000e+09  1.610000e+09
# Bhutan                                   NaN           NaN           NaN
# Bolivia                         6.510000e+09  6.960000e+09  6.120000e+09
# Bosnia and Herzegovina                   NaN           NaN           NaN
# Botswana                        2.960000e+08  3.140000e+08  3.470000e+08
# Brazil                          3.220000e+11  3.370000e+11  3.760000e+11
# Brunei                                   NaN           NaN           NaN
# Bulgaria                                 NaN           NaN           NaN
# Burkina Faso                    1.340000e+09  1.460000e+09  1.510000e+09
# Burundi                         6.760000e+08  7.690000e+08  7.670000e+08
# Cambodia                                 NaN           NaN           NaN
# Cameroon                        5.920000e+09  5.270000e+09  5.610000e+09
# Canada                          4.460000e+11  4.590000e+11  4.830000e+11
# ...                                      ...           ...           ...
# Sri Lanka                       7.060000e+09  7.510000e+09  7.950000e+09
# St. Kitts and Nevis                      NaN           NaN           NaN
# St. Lucia                                NaN           NaN           NaN
# St. Vincent and the Grenadines  1.510000e+08  1.360000e+08  1.450000e+08
# Sudan                           9.860000e+09  1.000000e+10  1.020000e+10
# Suriname                                 NaN           NaN           NaN
# Sweden                          1.780000e+11  1.840000e+11  1.910000e+11
# Switzerland                              NaN           NaN           NaN
# Tajikistan                               NaN           NaN           NaN
# Tanzania                                 NaN           NaN           NaN
# Thailand                        2.460000e+10  2.670000e+10  2.890000e+10
# Timor-Leste                              NaN           NaN           NaN
# Togo                            9.730000e+08  1.030000e+09  1.080000e+09
# Tonga                                    NaN           NaN           NaN
# Trinidad and Tobago             5.970000e+09  6.090000e+09  6.410000e+09
# Tunisia                         5.230000e+09  5.240000e+09  5.790000e+09
# Turkey                          1.230000e+11  1.280000e+11  1.370000e+11
# Tuvalu                                   NaN           NaN           NaN
# Uganda                                   NaN           NaN           NaN
# Ukraine                                  NaN           NaN           NaN
# United Kingdom                  8.630000e+11  8.830000e+11  9.180000e+11
# United States                   4.180000e+12  4.290000e+12  4.490000e+12
# Uruguay                         1.500000e+10  1.440000e+10  1.470000e+10
# Uzbekistan                               NaN           NaN           NaN
# Vanuatu                                  NaN           NaN           NaN
# Venezuela                       1.390000e+11  1.430000e+11  1.530000e+11
# Vietnam                                  NaN           NaN           NaN
# Yemen                                    NaN           NaN           NaN
# Zambia                          5.790000e+09  6.250000e+09  6.330000e+09
# Zimbabwe                        4.060000e+09  4.400000e+09  4.490000e+09
#
#                                     1969_PIB       ...            2011_EXP  \
# country                                            ...
# Afghanistan                              NaN       ...        3.040000e+09
# Albania                                  NaN       ...        3.770000e+09
# Algeria                         3.600000e+10       ...        7.640000e+10
# Angola                                   NaN       ...        6.800000e+10
# Antigua and Barbuda                      NaN       ...        5.380000e+08
# Argentina                       1.640000e+11       ...        9.760000e+10
# Armenia                                  NaN       ...        2.740000e+09
# Australia                       3.050000e+11       ...        3.240000e+11
# Austria                         1.370000e+11       ...        2.290000e+11
# Azerbaijan                               NaN       ...        3.700000e+10
# Bahamas                         4.520000e+09       ...        3.330000e+09
# Bahrain                                  NaN       ...        2.290000e+10
# Bangladesh                      2.500000e+10       ...        2.700000e+10
# Barbados                                 NaN       ...        2.150000e+09
# Belarus                                  NaN       ...        4.650000e+10
# Belgium                         1.840000e+11       ...        4.290000e+11
# Belize                          1.560000e+08       ...        9.440000e+08
# Benin                           1.660000e+09       ...        1.660000e+09
# Bhutan                                   NaN       ...        7.460000e+08
# Bolivia                         6.310000e+09       ...        9.120000e+09
# Bosnia and Herzegovina                   NaN       ...        5.980000e+09
# Botswana                        3.990000e+08       ...        7.350000e+09
# Brazil                          4.130000e+11       ...        2.920000e+11
# Brunei                                   NaN       ...        1.290000e+10
# Bulgaria                                 NaN       ...        3.400000e+10
# Burkina Faso                    1.540000e+09       ...        2.810000e+09
# Burundi                         7.550000e+08       ...        2.360000e+08
# Cambodia                                 NaN       ...        7.770000e+09
# Cameroon                        5.880000e+09       ...        7.510000e+09
# Canada                          5.090000e+11       ...        5.470000e+11
# ...                                      ...       ...                 ...
# Sri Lanka                       8.560000e+09       ...        1.360000e+10
# St. Kitts and Nevis                      NaN       ...        2.430000e+08
# St. Lucia                                NaN       ...        5.730000e+08
# St. Vincent and the Grenadines  1.490000e+08       ...        1.830000e+08
# Sudan                           1.030000e+10       ...        1.100000e+10
# Suriname                                 NaN       ...        2.850000e+09
# Sweden                          2.010000e+11       ...        2.620000e+11
# Switzerland                              NaN       ...        4.540000e+11
# Tajikistan                               NaN       ...        1.050000e+09
# Tanzania                                 NaN       ...        7.400000e+09
# Thailand                        3.080000e+10       ...        2.630000e+11
# Timor-Leste                              NaN       ...        1.010000e+08
# Togo                            1.200000e+09       ...        1.690000e+09
# Tonga                                    NaN       ...        6.740000e+07
# Trinidad and Tobago             6.580000e+09       ...        1.820000e+10
# Tunisia                         6.060000e+09       ...        2.250000e+10
# Turkey                          1.430000e+11       ...        1.840000e+11
# Tuvalu                                   NaN       ...        1.480000e+07
# Uganda                                   NaN       ...        4.300000e+09
# Ukraine                                  NaN       ...        8.370000e+10
# United Kingdom                  9.370000e+11       ...        8.020000e+11
# United States                   4.630000e+12       ...        2.130000e+12
# Uruguay                         1.560000e+10       ...        1.290000e+10
# Uzbekistan                               NaN       ...                 NaN
# Vanuatu                                  NaN       ...        3.510000e+08
# Venezuela                       1.540000e+11       ...        9.570000e+10
# Vietnam                                  NaN       ...        1.060000e+11
# Yemen                                    NaN       ...        1.040000e+10
# Zambia                          6.300000e+09       ...        9.420000e+09
# Zimbabwe                        5.040000e+09       ...        4.910000e+09
#
#                                     2012_EXP      2013_EXP      2014_EXP  \
# country
# Afghanistan                     2.320000e+09  1.390000e+09  1.990000e+09
# Albania                         3.560000e+09  3.700000e+09  3.730000e+09
# Algeria                         7.520000e+10  6.860000e+10  6.360000e+10
# Angola                          7.190000e+10  6.960000e+10  6.090000e+10
# Antigua and Barbuda             5.420000e+08  5.290000e+08  1.030000e+09
# Argentina                       9.430000e+10  8.960000e+10  8.180000e+10
# Armenia                         2.920000e+09  3.160000e+09  3.320000e+09
# Australia                       3.120000e+11  3.070000e+11  2.970000e+11
# Austria                         2.180000e+11  2.290000e+11  2.360000e+11
# Azerbaijan                      3.670000e+10  3.590000e+10  3.260000e+10
# Bahamas                         3.680000e+09  3.630000e+09  3.560000e+09
# Uzbekistan                      1.410000e+10           Não               0
# Vanuatu                                  NaN           Não               0
# Venezuela                                NaN      Mercosul               0
# Vietnam                                  NaN           Não               0
# Yemen                                    NaN           Não               0
# Zambia                          9.990000e+09           Não               0
# Zimbabwe                                 NaN           Não               0
#
# [180 rows x 121 columns]

# %% [markdown]
# ### Criando grafico de dispersão comparando ao ano de criação e no ano de 2016.

# %% [markdown]
# #### 1991

# %%
plt.scatter(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul",'1991_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul", '1991_EXP'], color="r")
plt.scatter(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados",'1991_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados", '1991_EXP'], color="b")
plt.title('Grafico de dispersão com Exportação e PIB em 1991')
# Out:
# Text(0.5, 1.0, 'Grafico de dispersão com Exportação e PIB em 1991')

# %% [markdown]
# #### 2016

# %%
plt.scatter(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul",'2016_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul", '2016_EXP'], color="y")
plt.scatter(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados",'2016_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados", '2016_EXP'], color="g")
plt.title('Grafico de dispersão com Exportação e PIB em 2016')
# Out:
# Text(0.5, 1.0, 'Grafico de dispersão com Exportação e PIB em 2016')

# %% [markdown]
# ### Gráficos conclusivos.

# %%
def reta(dados_x, dados_y, c):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()

    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
    plt.scatter(dados_x, dados_y, c=c, alpha=0.8)
    plt.title('x versus y')
    plt.xlabel('eixo x')
    plt.ylabel('eixo y')

    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color=c)

    plt.tight_layout()

# %% [markdown]
# #### 1991

# %%
plt.scatter(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul",'1991_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul", '1991_EXP'], color="r")
reta(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul",'1991_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul",'1991_EXP'], "r")
plt.scatter(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados",'1991_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados", '1991_EXP'], color="b")
reta(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados",'1991_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados",'1991_EXP'], "b")
plt.title('Grafico com as variaveis Exportação e PIB em 1991.')
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 5180070125.521915
# Coeficiente angular: 0.025820683078044065
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 4766935020.081351
# Coeficiente angular: 0.038665457406787236
# Text(0.5, 1.0, 'Grafico com as variaveis Exportação e PIB em 1991.')

# %% [markdown]
# #### 2016

# %%
plt.scatter(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul",'2016_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul", '2016_EXP'], color="y")
reta(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul",'2016_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Mercosul",'2016_EXP'], "y")
plt.scatter(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados",'2016_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados", '2016_EXP'], color="g")
reta(tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados",'2016_PIB'], tabela_pib_exp.loc[tabela_pib_exp.MERCOSUL_PIB=="Associados",'2016_EXP'], "g")
plt.title('Gráfico com variaveis Exportação e PIB em 2016.')
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 6103988515.962791
# Coeficiente angular: 0.09049304511145208
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 6007310899.732967
# Coeficiente angular: 0.15421714456591878
# Text(0.5, 1.0, 'Gráfico com variaveis Exportação e PIB em 2016.')

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Ao final da analise completa dos dados é possível observar que com a criação do bloco Mercosul os países membros tiveram um maior aumento na exportação acarretando no aumento do PIB.
# Mesmos apesar dos países associados ao mercosul não tenham tido um aumento como o dos países membros, os próprios exportaram mais e também tiveram aumento no PIB após a criação do bloco.
# Mesmos apesar dos países associados ao mercosul não tenham tido um aumento como o dos países membros, os próprios exportaram mais e também tiveram aumento no PIB após a criação do bloco.
